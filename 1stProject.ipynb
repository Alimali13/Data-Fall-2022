# %% [markdown]
# <a href="https://colab.research.google.com/github/Alimali13/Data-Fall-2022/blob/main/1stProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd #here i imported all required libraries and uploaded dataset
import numpy as np
import seaborn as sns
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv') #District Borough Number
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
df.head(10) #here a saw first 10 rows
# Out:
#   School DBN                     School Name School Level  \
# 0     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3     01M140          P.S. 140 Nathan Straus          K-8
# 4     01M140          P.S. 140 Nathan Straus          K-8
# 5     01M140          P.S. 140 Nathan Straus          K-8
# 6     01M140          P.S. 140 Nathan Straus          K-8
# 7     01M140          P.S. 140 Nathan Straus          K-8
# 8     01M184            P.S. 184m Shuang Wen          K-8
# 9     01M184            P.S. 184m Shuang Wen          K-8
#
#           Regents Exam  Year  Total Tested Mean Score Number Scoring Below 65  \
# 0  Common Core Algebra  2017             4          s                       s
# 1   Living Environment  2015            16       77.9                       1
# 2   Living Environment  2016             9         74                       1
# ...

# %%
df.isnull().sum() #here i checked missing values and noticed unexpected missing values as "s" and "na"
# Out:
# School DBN                      0
# School Name                     0
# School Level                    0
# Regents Exam                   10
# Year                            0
# Total Tested                    0
# Mean Score                      0
# Number Scoring Below 65         0
# Percent Scoring Below 65        0
# Number Scoring 65 or Above      0
# Percent Scoring 65 or Above     0
# Number Scoring 80 or Above      0
# Percent Scoring 80 or Above     0
# Number Scoring CR               0
# Percent Scoring CR              0
# dtype: int64

# %%
missing_values = ["s", "na"] #here i poimted out unexpected missing values

# %%
df=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values = missing_values) #here i uploaded updared dataset with missing values

# %%
df
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3          01M140          P.S. 140 Nathan Straus          K-8
# 4          01M140          P.S. 140 Nathan Straus          K-8
# ...           ...                             ...          ...
# 212326     84X717            Icahn Charter School          K-8
# 212327     84X717            Icahn Charter School          K-8
# 212328     84X717            Icahn Charter School          K-8
# 212329     84X717            Icahn Charter School          K-8
# 212330     84X717            Icahn Charter School          K-8
#
#                        Regents Exam  Year  Total Tested Mean Score  \
# 0               Common Core Algebra  2017             4          s
# 1                Living Environment  2015            16       77.9
# ...

# %%
df.isnull().sum() #here i can see real picture with all number of missing values
# Out:
# School DBN                          0
# School Name                         0
# School Level                        0
# Regents Exam                       10
# Year                                0
# Total Tested                        0
# Mean Score                      75222
# Number Scoring Below 65         75222
# Percent Scoring Below 65        75222
# Number Scoring 65 or Above      75222
# Percent Scoring 65 or Above     75222
# Number Scoring 80 or Above      75222
# Percent Scoring 80 or Above     75222
# Number Scoring CR              142680
# Percent Scoring CR             142680
# dtype: int64

# %%
#here i'll do reserch for 1st comparison - P.S. 034 Franklin D. Roosevelt school

# %%
df1=df
filter = df1["School Name"]=="P.S. 034 Franklin D. Roosevelt"
df1.where(filter, inplace = True)
df1
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 3             NaN                             NaN          NaN
# 4             NaN                             NaN          NaN
# ...           ...                             ...          ...
# 212326        NaN                             NaN          NaN
# 212327        NaN                             NaN          NaN
# 212328        NaN                             NaN          NaN
# 212329        NaN                             NaN          NaN
# 212330        NaN                             NaN          NaN
#
#                Regents Exam    Year  Total Tested Mean Score  \
# 0       Common Core Algebra  2017.0           4.0          s
# 1        Living Environment  2015.0          16.0       77.9
# ...

# %%
df1=df1.dropna(how='all') #here I deleted all missing values, if all cells i the raw missed
df1
# Out:
#        School DBN                     School Name School Level  \
# 0          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19478      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19479      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19480      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19481      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54234      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54235      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54236      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54237      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54238      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54239      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54240      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# ...

# %%
df1=df1.dropna(subset=['Mean Score'])
df1
# Out:
#        School DBN                     School Name School Level  \
# 1          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 2          01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19480      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 19481      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 54237      01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 102881     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 102882     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139886     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139888     01M034  P.S. 034 Franklin D. Roosevelt          K-8
# 139892     01M034  P.S. 034 Franklin D. Roosevelt          K-8
#
#               Regents Exam    Year  Total Tested  Mean Score  \
# 1       Living Environment  2015.0          16.0        77.9
# 2       Living Environment  2016.0           9.0        74.0
# 19480   Living Environment  2015.0          16.0        77.9
# ...

# %%
df1.describe()
# Out:
#               Year  Total Tested  Mean Score  Number Scoring Below 65  \
# count    10.000000     10.000000   10.000000                10.000000
# mean   2015.300000      9.400000   76.750000                 0.600000
# std       0.483046      3.777124    2.298429                 0.516398
# min    2015.000000      6.000000   73.500000                 0.000000
# 25%    2015.000000      6.250000   74.375000                 0.000000
# 50%    2015.000000      9.000000   77.900000                 1.000000
# 75%    2015.750000      9.750000   77.975000                 1.000000
# max    2016.000000     16.000000   80.000000                 1.000000
#
#        Percent Scoring Below 65  Number Scoring 65 or Above  \
# count                 10.000000                   10.000000
# mean                   6.260000                    8.800000
# std                    6.110319                    3.552777
# min                    0.000000                    5.000000
# ...

# %%
df1.groupby(['Regents Exam','Year'])['Mean Score'].median()
# Out:
# Regents Exam        Year
# Living Environment  2015.0    77.9
#                     2016.0    74.0
# Name: Mean Score, dtype: float64

# %%
df1.groupby(['Regents Exam','Year'])['Mean Score'].median().plot.bar()

# %%
missing_values = ["s", "na"]

# %%
df2=pd.read_csv('https://raw.githubusercontent.com/CunyLaguardiaDataAnalytics/datasets/master/2014-15_To_2016-17_School-_Level_NYC_Regents_Report_For_All_Variables.csv', na_values = missing_values)

# %%
filter = df2["School Name"]=="P.S. 184m Shuang Wen"
df2.where(filter, inplace = True)
df2
# Out:
#        School DBN School Name School Level Regents Exam  Year  Total Tested  \
# 0             NaN         NaN          NaN          NaN   NaN           NaN
# 1             NaN         NaN          NaN          NaN   NaN           NaN
# 2             NaN         NaN          NaN          NaN   NaN           NaN
# 3             NaN         NaN          NaN          NaN   NaN           NaN
# 4             NaN         NaN          NaN          NaN   NaN           NaN
# ...           ...         ...          ...          ...   ...           ...
# 212326        NaN         NaN          NaN          NaN   NaN           NaN
# 212327        NaN         NaN          NaN          NaN   NaN           NaN
# 212328        NaN         NaN          NaN          NaN   NaN           NaN
# 212329        NaN         NaN          NaN          NaN   NaN           NaN
# 212330        NaN         NaN          NaN          NaN   NaN           NaN
#
# ...

# %%
df2=df2.dropna(how='all') 
df2
# Out:
#        School DBN           School Name School Level         Regents Exam  \
# 8          01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 9          01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 10         01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 11         01M184  P.S. 184m Shuang Wen          K-8   Living Environment
# 19489      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19490      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19491      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19492      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19493      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19494      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 19495      01M184  P.S. 184m Shuang Wen          K-8   Living Environment
# 54250      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# ...

# %%
df2=df2.dropna(subset=['Mean Score'])
df2
# Out:
#        School DBN           School Name School Level         Regents Exam  \
# 8          01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 9          01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 10         01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 11         01M184  P.S. 184m Shuang Wen          K-8   Living Environment
# 19495      01M184  P.S. 184m Shuang Wen          K-8   Living Environment
# 54251      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 54254      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 54257      01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 54259      01M184  P.S. 184m Shuang Wen          K-8   Living Environment
# 54260      01M184  P.S. 184m Shuang Wen          K-8   Living Environment
# 102895     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# 102896     01M184  P.S. 184m Shuang Wen          K-8  Common Core Algebra
# ...

# %%
df2.groupby(['Regents Exam','Year'])['Mean Score'].median()
# Out:
# Regents Exam         Year
# Common Core Algebra  2015.0    78.4
#                      2016.0    79.0
#                      2017.0    84.9
# Living Environment   2017.0    83.9
# Name: Mean Score, dtype: float64

# %%
df2.groupby(['Regents Exam','Year'])['Mean Score'].median().plot.bar()

# %%
#select 2 or 3 schools in the separete table and after that clen data - deleate missing data and grpoup by
